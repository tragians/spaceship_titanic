# %% [markdown]
# ## In this notebook classification is perfromed with the XGBClassifier

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# ### Load and prepare data for training

# %%
df = pd.read_csv('~/spaceship_titanic/data/cleaned_train.csv')
df
# Out:
#       Unnamed: 0  HomePlanet  CryoSleep  Destination       Age  VIP  \
# 0              0           1          0            2  0.701070    0
# 1              1           0          0            2 -0.335103    0
# 2              2           1          0            2  2.013556    1
# 3              3           1          0            2  0.286601    0
# 4              4           0          0            2 -0.887728    0
# ...          ...         ...        ...          ...       ...  ...
# 7374        8688           1          0            1  0.839227    1
# 7375        8689           0          1            0 -0.749572    0
# 7376        8690           0          0            2 -0.196946    0
# 7377        8691           1          0            1  0.217523    0
# 7378        8692           1          0            2  1.046461    0
#
#       RoomService  FoodCourt  ShoppingMall       Spa    VRDeck  Transported  \
# 0       -0.342904  -0.279405     -0.308027 -0.269982 -0.266422            0
# 1       -0.171788  -0.273878     -0.263923  0.223638 -0.227164            1
# 2       -0.275399   1.916461     -0.308027  5.767644 -0.222703            0
# 3       -0.342904   0.508430      0.346484  2.723206 -0.094224            0
# 4        0.132767  -0.236421     -0.041636  0.238024 -0.264637            1
# ...           ...        ...           ...       ...       ...          ...
# 7374    -0.342904   3.907846     -0.308027  1.207281 -0.200398            0
# 7375    -0.342904  -0.279405     -0.308027 -0.269982 -0.266422            0
# 7376    -0.342904  -0.279405      2.994519 -0.269082 -0.266422            1
# 7377    -0.342904   0.364741     -0.308027  0.047410  2.619897            0
# 7378    -0.145100   2.599292     -0.308027 -0.269982 -0.255715            1
#
#       Dec  Side  CabinCrowdness
# 0       3     0       -0.563210
# 1       5     1       -0.563210
# 2       4     1        0.271984
# 3       4     1        0.271984
# 4       5     1       -0.563210
# ...   ...   ...             ...
# 7374    4     0       -0.563210
# 7375    6     1       -0.563210
# 7376    6     1       -0.563210
# 7377    0     1        0.271984
# 7378    0     1        0.271984
#
# [7379 rows x 15 columns]

# %%
X = df.drop('Transported', axis=1)
y = df['Transported']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# ### Basic hyperparameter tuning

# %% [markdown]
# Grid search on max_depth and min_child_weight

# %%
param_test1 = {
 'max_depth':range(3,10,2),
 'min_child_weight':range(1,6,2)
}
gsearch1 = GridSearchCV(estimator = XGBClassifier(objective= 'binary:logistic', learning_rate =0.1, max_depth=5, 
min_child_weight=1, gamma=0.1, subsample=0.8, colsample_bytree=0.8, scale_pos_weight=1, seed=0), 
 param_grid = param_test1, scoring='accuracy', cv = 5)
gsearch1.fit(X_train,y_train)
gsearch1.best_params_, gsearch1.best_score_
# Out:
# ({'max_depth': 5, 'min_child_weight': 1}, 0.8084564606948058)

# %% [markdown]
# Grid search on regularization weight gamma

# %%
param_test2 = {
 'gamma':[i/10.0 for i in range(0,5)],
    'reg_alpha':[0, 0.001, 0.005, 0.01, 0.05]
}
gsearch2 = GridSearchCV(estimator = XGBClassifier(objective= 'binary:logistic', learning_rate =0.1, max_depth=5,
 min_child_weight=1, gamma=0.1, subsample=0.8, colsample_bytree=0.8, scale_pos_weight=1, seed=0), 
 param_grid = param_test2, scoring='accuracy', cv = 5)
gsearch2.fit(X_train,y_train)
gsearch2.best_params_, gsearch2.best_score_
# Out:
# ({'gamma': 0.3, 'reg_alpha': 0.05}, 0.8111668145011768)

# %% [markdown]
# Grid search on num_of_estimators

# %%
param_test3 = {
 'n_estimators':range(100,160,10),
}
gsearch3 = GridSearchCV(estimator = XGBClassifier(objective= 'binary:logistic', learning_rate =0.1, max_depth=5,
 min_child_weight=1, gamma=0.3, reg_alpha = 0.05, subsample=0.8, colsample_bytree=0.8, scale_pos_weight=1, seed=0), 
 param_grid = param_test2, scoring='accuracy', cv = 5)
gsearch3.fit(X_train,y_train)
gsearch3.best_params_, gsearch3.best_score_
# Out:
# ({'gamma': 0.3, 'reg_alpha': 0.05}, 0.8111668145011768)

# %% [markdown]
# ### Start training with optimal hyperparameters

# %%
# Set the parameters for the XGBoost model
params = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'max_depth': 5,
    'min_child_weight': 1,
    'n_estimators': 100,
    'learning_rate': 0.1,
    'gamma': 0.3,
    'reg_alpha':0.05,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'scale_pos_weight':1, 
    'seed': 0
}
# Train the XGBoost model
clf = XGBClassifier(**params)
clf.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=True);

# Predict on the validation set
y_pred = clf.predict(X_val)

# Convert probabilities to binary predictions
y_pred_binary = [1 if p >= 0.5 else 0 for p in y_pred]
# Out:
# [0]	validation_0-logloss:0.65705
# [1]	validation_0-logloss:0.62674
# [2]	validation_0-logloss:0.60341
# [3]	validation_0-logloss:0.58242
# [4]	validation_0-logloss:0.56156
# [5]	validation_0-logloss:0.54513
# [6]	validation_0-logloss:0.52848
# [7]	validation_0-logloss:0.51714
# [8]	validation_0-logloss:0.50591
# [9]	validation_0-logloss:0.49541
# [10]	validation_0-logloss:0.48666
# [11]	validation_0-logloss:0.47906
# [12]	validation_0-logloss:0.47148
# [13]	validation_0-logloss:0.46581
# [14]	validation_0-logloss:0.45990
# [15]	validation_0-logloss:0.45508
# [16]	validation_0-logloss:0.45099
# [17]	validation_0-logloss:0.44770
# [18]	validation_0-logloss:0.44403
# [19]	validation_0-logloss:0.44072
# [20]	validation_0-logloss:0.43802
# [21]	validation_0-logloss:0.43512
# [22]	validation_0-logloss:0.43332
# [23]	validation_0-logloss:0.43140
# [24]	validation_0-logloss:0.42963
# [25]	validation_0-logloss:0.42605
# [26]	validation_0-logloss:0.42483
# [27]	validation_0-logloss:0.42301
# [28]	validation_0-logloss:0.42050
# [29]	validation_0-logloss:0.41950
# [30]	validation_0-logloss:0.41868
# [31]	validation_0-logloss:0.41826
# [32]	validation_0-logloss:0.41707
# [33]	validation_0-logloss:0.41589
# [34]	validation_0-logloss:0.41503
# [35]	validation_0-logloss:0.41370
# [36]	validation_0-logloss:0.41332
# [37]	validation_0-logloss:0.41278
# [38]	validation_0-logloss:0.41170
# [39]	validation_0-logloss:0.41082
# [40]	validation_0-logloss:0.41052
# [41]	validation_0-logloss:0.40953
# [42]	validation_0-logloss:0.40855
# [43]	validation_0-logloss:0.40794
# [44]	validation_0-logloss:0.40764
# [45]	validation_0-logloss:0.40724
# [46]	validation_0-logloss:0.40695
# [47]	validation_0-logloss:0.40620
# [48]	validation_0-logloss:0.40596
# [49]	validation_0-logloss:0.40543
# [50]	validation_0-logloss:0.40539
# [51]	validation_0-logloss:0.40397
# [52]	validation_0-logloss:0.40367
# [53]	validation_0-logloss:0.40389
# [54]	validation_0-logloss:0.40341
# [55]	validation_0-logloss:0.40316
# [56]	validation_0-logloss:0.40238
# [57]	validation_0-logloss:0.40154
# [58]	validation_0-logloss:0.40129
# [59]	validation_0-logloss:0.40060
# [60]	validation_0-logloss:0.40056
# [61]	validation_0-logloss:0.40028
# [62]	validation_0-logloss:0.39966
# [63]	validation_0-logloss:0.39910
# [64]	validation_0-logloss:0.39908
# [65]	validation_0-logloss:0.39889
# [66]	validation_0-logloss:0.39863
# [67]	validation_0-logloss:0.39855
# [68]	validation_0-logloss:0.39821
# [69]	validation_0-logloss:0.39855
# [70]	validation_0-logloss:0.39862
# [71]	validation_0-logloss:0.39831
# [72]	validation_0-logloss:0.39823
# [73]	validation_0-logloss:0.39791
# [74]	validation_0-logloss:0.39791
# [75]	validation_0-logloss:0.39803
# [76]	validation_0-logloss:0.39758
# [77]	validation_0-logloss:0.39753
# [78]	validation_0-logloss:0.39727
# [79]	validation_0-logloss:0.39689
# [80]	validation_0-logloss:0.39672
# [81]	validation_0-logloss:0.39660
# [82]	validation_0-logloss:0.39640
# [83]	validation_0-logloss:0.39641
# [84]	validation_0-logloss:0.39613
# [85]	validation_0-logloss:0.39608
# [86]	validation_0-logloss:0.39612
# [87]	validation_0-logloss:0.39606
# [88]	validation_0-logloss:0.39610
# [89]	validation_0-logloss:0.39581
# [90]	validation_0-logloss:0.39572
# [91]	validation_0-logloss:0.39619
# [92]	validation_0-logloss:0.39567
# [93]	validation_0-logloss:0.39535
# [94]	validation_0-logloss:0.39542
# [95]	validation_0-logloss:0.39512
# [96]	validation_0-logloss:0.39510
# [97]	validation_0-logloss:0.39505
# [98]	validation_0-logloss:0.39457
# [99]	validation_0-logloss:0.39414

# %%
# Generate classification report
classification_rep = classification_report(y_val, y_pred_binary)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       902
#            1       0.82      0.79      0.81       943
#
#     accuracy                           0.80      1845
#    macro avg       0.80      0.80      0.80      1845
# weighted avg       0.80      0.80      0.80      1845
